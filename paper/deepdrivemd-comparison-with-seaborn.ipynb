# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
index = ['Stage 1\n (MD simulation)',
 'Stage 2\n (Aggregation)',
 'Stage 3\n (Training)',
 'Stage 4\n (Inference)']

column = ['Original+NFS',
 'Original+BFS',
 'Shortened+NFS',
 'Shortened+BFS',
 'Shortened+BFS+RAMDISK']

# %%
col_idx = 0
orig_nfs = [[column[col_idx], index[0], 24.187],
             [column[col_idx], index[1], 2.454],
             [column[col_idx], index[2], 55.865],
             [column[col_idx], index[3], 10.198],              
            ]
col_idx = 1
orig_bfs = [[column[col_idx], index[0], 21.698],
             [column[col_idx], index[1], 1.719],
             [column[col_idx], index[2], 45.014],
             [column[col_idx], index[3], 10.604],              
            ]
col_idx = 2
short_nfs = [[column[col_idx], index[0], 16.8],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 26.4/2],
            [column[col_idx], index[3], 26.4/2]]
col_idx = 3
short_bfs = [[column[col_idx], index[0], 15.6],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 24.2/2],
            [column[col_idx], index[3], 24.2/2]]
col_idx = 4
short_bfs_ramdisk = [[column[col_idx], index[0], 15.80],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 25/2],
            [column[col_idx], index[3], 25/2]]
data = orig_nfs + orig_bfs + short_nfs + short_bfs + short_bfs_ramdisk
data
# Out:
# [['Original+NFS', 'Stage 1\n (MD simulation)', 24.187],
#  ['Original+NFS', 'Stage 2\n (Aggregation)', 2.454],
#  ['Original+NFS', 'Stage 3\n (Training)', 55.865],
#  ['Original+NFS', 'Stage 4\n (Inference)', 10.198],
#  ['Original+BFS', 'Stage 1\n (MD simulation)', 21.698],
#  ['Original+BFS', 'Stage 2\n (Aggregation)', 1.719],
#  ['Original+BFS', 'Stage 3\n (Training)', 45.014],
#  ['Original+BFS', 'Stage 4\n (Inference)', 10.604],
#  ['Shortened+NFS', 'Stage 1\n (MD simulation)', 16.8],
#  ['Shortened+NFS', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+NFS', 'Stage 3\n (Training)', 13.2],
#  ['Shortened+NFS', 'Stage 4\n (Inference)', 13.2],
#  ['Shortened+BFS', 'Stage 1\n (MD simulation)', 15.6],
#  ['Shortened+BFS', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+BFS', 'Stage 3\n (Training)', 12.1],
#  ['Shortened+BFS', 'Stage 4\n (Inference)', 12.1],
#  ['Shortened+BFS+RAMDISK', 'Stage 1\n (MD simulation)', 15.8],
#  ['Shortened+BFS+RAMDISK', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+BFS+RAMDISK', 'Stage 3\n (Training)', 12.5],
#  ['Shortened+BFS+RAMDISK', 'Stage 4\n (Inference)', 12.5]]

# %%
df__ = pd.DataFrame(data, columns=['configuration', 'stage', 'value'])
df__
# Out:
#             configuration                      stage   value
# 0            Original+NFS  Stage 1\n (MD simulation)  24.187
# 1            Original+NFS    Stage 2\n (Aggregation)   2.454
# 2            Original+NFS       Stage 3\n (Training)  55.865
# 3            Original+NFS      Stage 4\n (Inference)  10.198
# 4            Original+BFS  Stage 1\n (MD simulation)  21.698
# 5            Original+BFS    Stage 2\n (Aggregation)   1.719
# 6            Original+BFS       Stage 3\n (Training)  45.014
# 7            Original+BFS      Stage 4\n (Inference)  10.604
# 8           Shortened+NFS  Stage 1\n (MD simulation)  16.800
# 9           Shortened+NFS    Stage 2\n (Aggregation)   0.000
# 10          Shortened+NFS       Stage 3\n (Training)  13.200
# 11          Shortened+NFS      Stage 4\n (Inference)  13.200
# 12          Shortened+BFS  Stage 1\n (MD simulation)  15.600
# 13          Shortened+BFS    Stage 2\n (Aggregation)   0.000
# 14          Shortened+BFS       Stage 3\n (Training)  12.100
# 15          Shortened+BFS      Stage 4\n (Inference)  12.100
# 16  Shortened+BFS+RAMDISK  Stage 1\n (MD simulation)  15.800
# 17  Shortened+BFS+RAMDISK    Stage 2\n (Aggregation)   0.000
# 18  Shortened+BFS+RAMDISK       Stage 3\n (Training)  12.500
# 19  Shortened+BFS+RAMDISK      Stage 4\n (Inference)  12.500

# %%
ax = sns.barplot(df__, x='stage', y='value', hue='configuration')
ax.set(ylabel='second')
plt.show()

# %%
fig = ax.get_figure()
fig.savefig("ddmd_jobs_comparison.pdf")
