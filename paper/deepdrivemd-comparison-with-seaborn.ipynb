# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
index = ['Stage 1\n (MD simulation)',
 'Stage 2\n (Aggregation)',
 'Stage 3\n (Training)',
 'Stage 4\n (Inference)']

column = ['Original+NFS',
 'Original+BFS',
 'Shortened+NFS',
 'Shortened+BFS',
 'Shortened+BFS+RAMDISK']

# %%
col_idx = 0
orig_nfs = [[column[col_idx], index[0], 23.049],
             [column[col_idx], index[1], 1.884],
             [column[col_idx], index[2], 48.511],
             [column[col_idx], index[3], 9.933],
            
            [column[col_idx], index[0], 24.187],
             [column[col_idx], index[1], 2.454],
             [column[col_idx], index[2], 55.865],
             [column[col_idx], index[3], 10.198],
            
            [column[col_idx], index[0], 23.498],
             [column[col_idx], index[1], 1.702],
             [column[col_idx], index[2], 46.974],
             [column[col_idx], index[3], 9.214],
            ]
col_idx = 1
orig_bfs = [
            #/rcfs/projects/chess/leeh736/ddmd_runs/beefs_5th
            [column[col_idx], index[0], 23.924],
             [column[col_idx], index[1], 1.937],
             [column[col_idx], index[2], 45.014],
             [column[col_idx], index[3], 10.604],
            
            [column[col_idx], index[0], 23.076],
             [column[col_idx], index[1], 2.36],
             [column[col_idx], index[2], 46.197],
             [column[col_idx], index[3], 9.454],
            
            [column[col_idx], index[0], 24.218],
             [column[col_idx], index[1], 1.595],
             [column[col_idx], index[2], 46.147],
             [column[col_idx], index[3], 10.234],
            ]
col_idx = 2
short_nfs = [[column[col_idx], index[0], 15.99],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 28.38/2],
            [column[col_idx], index[3], 28.38/2],
            [column[col_idx], index[0], 16.24],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 28.99/2],
            [column[col_idx], index[3], 28.99/2],
            [column[col_idx], index[0], 15.86],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 28.86/2],
            [column[col_idx], index[3], 28.86/2]]
col_idx = 3
short_bfs = [[column[col_idx], index[0], 16.57],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 25.86/2],
            [column[col_idx], index[3], 25.86/2],
             [column[col_idx], index[0], 16],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 25.68/2],
            [column[col_idx], index[3], 25.68/2],
             [column[col_idx], index[0], 16.4],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 26.5/2],
            [column[col_idx], index[3], 26.5/2]
            ]
col_idx = 4
short_bfs_ramdisk = [[column[col_idx], index[0], 15.17],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 25.22/2],
            [column[col_idx], index[3], 25.22/2],
                    [column[col_idx], index[0], 13.35],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 26.29/2],
            [column[col_idx], index[3], 26.29/2],
                     [column[col_idx], index[0], 14.95],
            [column[col_idx], index[1], 0],
            [column[col_idx], index[2], 25.25/2],
            [column[col_idx], index[3], 25.25/2]
                    ]
data = orig_nfs + orig_bfs + short_nfs + short_bfs + short_bfs_ramdisk
data
# Out:
# [['Original+NFS', 'Stage 1\n (MD simulation)', 23.049],
#  ['Original+NFS', 'Stage 2\n (Aggregation)', 1.884],
#  ['Original+NFS', 'Stage 3\n (Training)', 48.511],
#  ['Original+NFS', 'Stage 4\n (Inference)', 9.933],
#  ['Original+NFS', 'Stage 1\n (MD simulation)', 24.187],
#  ['Original+NFS', 'Stage 2\n (Aggregation)', 2.454],
#  ['Original+NFS', 'Stage 3\n (Training)', 55.865],
#  ['Original+NFS', 'Stage 4\n (Inference)', 10.198],
#  ['Original+NFS', 'Stage 1\n (MD simulation)', 23.498],
#  ['Original+NFS', 'Stage 2\n (Aggregation)', 1.702],
#  ['Original+NFS', 'Stage 3\n (Training)', 46.974],
#  ['Original+NFS', 'Stage 4\n (Inference)', 9.214],
#  ['Original+BFS', 'Stage 1\n (MD simulation)', 23.924],
#  ['Original+BFS', 'Stage 2\n (Aggregation)', 1.937],
#  ['Original+BFS', 'Stage 3\n (Training)', 45.014],
#  ['Original+BFS', 'Stage 4\n (Inference)', 10.604],
#  ['Original+BFS', 'Stage 1\n (MD simulation)', 23.076],
#  ['Original+BFS', 'Stage 2\n (Aggregation)', 2.36],
#  ['Original+BFS', 'Stage 3\n (Training)', 46.197],
#  ['Original+BFS', 'Stage 4\n (Inference)', 9.454],
#  ['Original+BFS', 'Stage 1\n (MD simulation)', 24.218],
#  ['Original+BFS', 'Stage 2\n (Aggregation)', 1.595],
#  ['Original+BFS', 'Stage 3\n (Training)', 46.147],
#  ['Original+BFS', 'Stage 4\n (Inference)', 10.234],
#  ['Shortened+NFS', 'Stage 1\n (MD simulation)', 15.99],
#  ['Shortened+NFS', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+NFS', 'Stage 3\n (Training)', 14.19],
#  ['Shortened+NFS', 'Stage 4\n (Inference)', 14.19],
#  ['Shortened+NFS', 'Stage 1\n (MD simulation)', 16.24],
#  ['Shortened+NFS', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+NFS', 'Stage 3\n (Training)', 14.495],
#  ['Shortened+NFS', 'Stage 4\n (Inference)', 14.495],
#  ['Shortened+NFS', 'Stage 1\n (MD simulation)', 15.86],
#  ['Shortened+NFS', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+NFS', 'Stage 3\n (Training)', 14.43],
#  ['Shortened+NFS', 'Stage 4\n (Inference)', 14.43],
#  ['Shortened+BFS', 'Stage 1\n (MD simulation)', 16.57],
#  ['Shortened+BFS', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+BFS', 'Stage 3\n (Training)', 12.93],
#  ['Shortened+BFS', 'Stage 4\n (Inference)', 12.93],
#  ['Shortened+BFS', 'Stage 1\n (MD simulation)', 16],
#  ['Shortened+BFS', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+BFS', 'Stage 3\n (Training)', 12.84],
#  ['Shortened+BFS', 'Stage 4\n (Inference)', 12.84],
#  ['Shortened+BFS', 'Stage 1\n (MD simulation)', 16.4],
#  ['Shortened+BFS', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+BFS', 'Stage 3\n (Training)', 13.25],
#  ['Shortened+BFS', 'Stage 4\n (Inference)', 13.25],
#  ['Shortened+BFS+RAMDISK', 'Stage 1\n (MD simulation)', 15.17],
#  ['Shortened+BFS+RAMDISK', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+BFS+RAMDISK', 'Stage 3\n (Training)', 12.61],
#  ['Shortened+BFS+RAMDISK', 'Stage 4\n (Inference)', 12.61],
#  ['Shortened+BFS+RAMDISK', 'Stage 1\n (MD simulation)', 13.35],
#  ['Shortened+BFS+RAMDISK', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+BFS+RAMDISK', 'Stage 3\n (Training)', 13.145],
#  ['Shortened+BFS+RAMDISK', 'Stage 4\n (Inference)', 13.145],
#  ['Shortened+BFS+RAMDISK', 'Stage 1\n (MD simulation)', 14.95],
#  ['Shortened+BFS+RAMDISK', 'Stage 2\n (Aggregation)', 0],
#  ['Shortened+BFS+RAMDISK', 'Stage 3\n (Training)', 12.625],
#  ['Shortened+BFS+RAMDISK', 'Stage 4\n (Inference)', 12.625]]

# %%
df__ = pd.DataFrame(data, columns=['configuration', 'stage', 'value'])
df__
# Out:
#             configuration                      stage   value
# 0            Original+NFS  Stage 1\n (MD simulation)  23.049
# 1            Original+NFS    Stage 2\n (Aggregation)   1.884
# 2            Original+NFS       Stage 3\n (Training)  48.511
# 3            Original+NFS      Stage 4\n (Inference)   9.933
# 4            Original+NFS  Stage 1\n (MD simulation)  24.187
# 5            Original+NFS    Stage 2\n (Aggregation)   2.454
# 6            Original+NFS       Stage 3\n (Training)  55.865
# 7            Original+NFS      Stage 4\n (Inference)  10.198
# 8            Original+NFS  Stage 1\n (MD simulation)  23.498
# 9            Original+NFS    Stage 2\n (Aggregation)   1.702
# 10           Original+NFS       Stage 3\n (Training)  46.974
# 11           Original+NFS      Stage 4\n (Inference)   9.214
# 12           Original+BFS  Stage 1\n (MD simulation)  23.924
# 13           Original+BFS    Stage 2\n (Aggregation)   1.937
# 14           Original+BFS       Stage 3\n (Training)  45.014
# 15           Original+BFS      Stage 4\n (Inference)  10.604
# 16           Original+BFS  Stage 1\n (MD simulation)  23.076
# 17           Original+BFS    Stage 2\n (Aggregation)   2.360
# 18           Original+BFS       Stage 3\n (Training)  46.197
# 19           Original+BFS      Stage 4\n (Inference)   9.454
# 20           Original+BFS  Stage 1\n (MD simulation)  24.218
# 21           Original+BFS    Stage 2\n (Aggregation)   1.595
# 22           Original+BFS       Stage 3\n (Training)  46.147
# 23           Original+BFS      Stage 4\n (Inference)  10.234
# 24          Shortened+NFS  Stage 1\n (MD simulation)  15.990
# 25          Shortened+NFS    Stage 2\n (Aggregation)   0.000
# 26          Shortened+NFS       Stage 3\n (Training)  14.190
# 27          Shortened+NFS      Stage 4\n (Inference)  14.190
# 28          Shortened+NFS  Stage 1\n (MD simulation)  16.240
# 29          Shortened+NFS    Stage 2\n (Aggregation)   0.000
# 30          Shortened+NFS       Stage 3\n (Training)  14.495
# 31          Shortened+NFS      Stage 4\n (Inference)  14.495
# 32          Shortened+NFS  Stage 1\n (MD simulation)  15.860
# 33          Shortened+NFS    Stage 2\n (Aggregation)   0.000
# 34          Shortened+NFS       Stage 3\n (Training)  14.430
# 35          Shortened+NFS      Stage 4\n (Inference)  14.430
# 36          Shortened+BFS  Stage 1\n (MD simulation)  16.570
# 37          Shortened+BFS    Stage 2\n (Aggregation)   0.000
# 38          Shortened+BFS       Stage 3\n (Training)  12.930
# 39          Shortened+BFS      Stage 4\n (Inference)  12.930
# 40          Shortened+BFS  Stage 1\n (MD simulation)  16.000
# 41          Shortened+BFS    Stage 2\n (Aggregation)   0.000
# 42          Shortened+BFS       Stage 3\n (Training)  12.840
# 43          Shortened+BFS      Stage 4\n (Inference)  12.840
# 44          Shortened+BFS  Stage 1\n (MD simulation)  16.400
# 45          Shortened+BFS    Stage 2\n (Aggregation)   0.000
# 46          Shortened+BFS       Stage 3\n (Training)  13.250
# 47          Shortened+BFS      Stage 4\n (Inference)  13.250
# 48  Shortened+BFS+RAMDISK  Stage 1\n (MD simulation)  15.170
# 49  Shortened+BFS+RAMDISK    Stage 2\n (Aggregation)   0.000
# 50  Shortened+BFS+RAMDISK       Stage 3\n (Training)  12.610
# 51  Shortened+BFS+RAMDISK      Stage 4\n (Inference)  12.610
# 52  Shortened+BFS+RAMDISK  Stage 1\n (MD simulation)  13.350
# 53  Shortened+BFS+RAMDISK    Stage 2\n (Aggregation)   0.000
# 54  Shortened+BFS+RAMDISK       Stage 3\n (Training)  13.145
# 55  Shortened+BFS+RAMDISK      Stage 4\n (Inference)  13.145
# 56  Shortened+BFS+RAMDISK  Stage 1\n (MD simulation)  14.950
# 57  Shortened+BFS+RAMDISK    Stage 2\n (Aggregation)   0.000
# 58  Shortened+BFS+RAMDISK       Stage 3\n (Training)  12.625
# 59  Shortened+BFS+RAMDISK      Stage 4\n (Inference)  12.625

# %%
ret = []
for i in column:
    cnt = 0
    total_ = 0
    for k, v in df__[df__['configuration']==i].iterrows():
        cnt += 1
        total_ += v['value']
        if cnt == 4:
            tmp = [i, 'Total', total_]
            ret.append(tmp)
            cnt = 0
            total_ = 0

# %%
ret
# Out:
# [['Original+NFS', 'Total', 83.37700000000001],
#  ['Original+NFS', 'Total', 92.70400000000001],
#  ['Original+NFS', 'Total', 81.388],
#  ['Original+BFS', 'Total', 81.479],
#  ['Original+BFS', 'Total', 81.08700000000002],
#  ['Original+BFS', 'Total', 82.19399999999999],
#  ['Shortened+NFS', 'Total', 44.37],
#  ['Shortened+NFS', 'Total', 45.23],
#  ['Shortened+NFS', 'Total', 44.72],
#  ['Shortened+BFS', 'Total', 42.43],
#  ['Shortened+BFS', 'Total', 41.68],
#  ['Shortened+BFS', 'Total', 42.9],
#  ['Shortened+BFS+RAMDISK', 'Total', 40.39],
#  ['Shortened+BFS+RAMDISK', 'Total', 39.64],
#  ['Shortened+BFS+RAMDISK', 'Total', 40.2]]

# %%
df_ = pd.DataFrame(ret, columns=['configuration', 'stage', 'value'])
df_
# Out:
#             configuration  stage   value
# 0            Original+NFS  Total  83.377
# 1            Original+NFS  Total  92.704
# 2            Original+NFS  Total  81.388
# 3            Original+BFS  Total  81.479
# 4            Original+BFS  Total  81.087
# 5            Original+BFS  Total  82.194
# 6           Shortened+NFS  Total  44.370
# 7           Shortened+NFS  Total  45.230
# 8           Shortened+NFS  Total  44.720
# 9           Shortened+BFS  Total  42.430
# 10          Shortened+BFS  Total  41.680
# 11          Shortened+BFS  Total  42.900
# 12  Shortened+BFS+RAMDISK  Total  40.390
# 13  Shortened+BFS+RAMDISK  Total  39.640
# 14  Shortened+BFS+RAMDISK  Total  40.200

# %%
df_all = pd.concat([df__, df_], ignore_index=True)

# %%
df__
# Out:
#             configuration                      stage   value
# 0            Original+NFS  Stage 1\n (MD simulation)  23.049
# 1            Original+NFS    Stage 2\n (Aggregation)   1.884
# 2            Original+NFS       Stage 3\n (Training)  48.511
# 3            Original+NFS      Stage 4\n (Inference)   9.933
# 4            Original+NFS  Stage 1\n (MD simulation)  24.187
# 5            Original+NFS    Stage 2\n (Aggregation)   2.454
# 6            Original+NFS       Stage 3\n (Training)  55.865
# 7            Original+NFS      Stage 4\n (Inference)  10.198
# 8            Original+NFS  Stage 1\n (MD simulation)  23.498
# 9            Original+NFS    Stage 2\n (Aggregation)   1.702
# 10           Original+NFS       Stage 3\n (Training)  46.974
# 11           Original+NFS      Stage 4\n (Inference)   9.214
# 12           Original+BFS  Stage 1\n (MD simulation)  23.924
# 13           Original+BFS    Stage 2\n (Aggregation)   1.937
# 14           Original+BFS       Stage 3\n (Training)  45.014
# 15           Original+BFS      Stage 4\n (Inference)  10.604
# 16           Original+BFS  Stage 1\n (MD simulation)  23.076
# 17           Original+BFS    Stage 2\n (Aggregation)   2.360
# 18           Original+BFS       Stage 3\n (Training)  46.197
# 19           Original+BFS      Stage 4\n (Inference)   9.454
# 20           Original+BFS  Stage 1\n (MD simulation)  24.218
# 21           Original+BFS    Stage 2\n (Aggregation)   1.595
# 22           Original+BFS       Stage 3\n (Training)  46.147
# 23           Original+BFS      Stage 4\n (Inference)  10.234
# 24          Shortened+NFS  Stage 1\n (MD simulation)  15.990
# 25          Shortened+NFS    Stage 2\n (Aggregation)   0.000
# 26          Shortened+NFS       Stage 3\n (Training)  14.190
# 27          Shortened+NFS      Stage 4\n (Inference)  14.190
# 28          Shortened+NFS  Stage 1\n (MD simulation)  16.240
# 29          Shortened+NFS    Stage 2\n (Aggregation)   0.000
# 30          Shortened+NFS       Stage 3\n (Training)  14.495
# 31          Shortened+NFS      Stage 4\n (Inference)  14.495
# 32          Shortened+NFS  Stage 1\n (MD simulation)  15.860
# 33          Shortened+NFS    Stage 2\n (Aggregation)   0.000
# 34          Shortened+NFS       Stage 3\n (Training)  14.430
# 35          Shortened+NFS      Stage 4\n (Inference)  14.430
# 36          Shortened+BFS  Stage 1\n (MD simulation)  16.570
# 37          Shortened+BFS    Stage 2\n (Aggregation)   0.000
# 38          Shortened+BFS       Stage 3\n (Training)  12.930
# 39          Shortened+BFS      Stage 4\n (Inference)  12.930
# 40          Shortened+BFS  Stage 1\n (MD simulation)  16.000
# 41          Shortened+BFS    Stage 2\n (Aggregation)   0.000
# 42          Shortened+BFS       Stage 3\n (Training)  12.840
# 43          Shortened+BFS      Stage 4\n (Inference)  12.840
# 44          Shortened+BFS  Stage 1\n (MD simulation)  16.400
# 45          Shortened+BFS    Stage 2\n (Aggregation)   0.000
# 46          Shortened+BFS       Stage 3\n (Training)  13.250
# 47          Shortened+BFS      Stage 4\n (Inference)  13.250
# 48  Shortened+BFS+RAMDISK  Stage 1\n (MD simulation)  15.170
# 49  Shortened+BFS+RAMDISK    Stage 2\n (Aggregation)   0.000
# 50  Shortened+BFS+RAMDISK       Stage 3\n (Training)  12.610
# 51  Shortened+BFS+RAMDISK      Stage 4\n (Inference)  12.610
# 52  Shortened+BFS+RAMDISK  Stage 1\n (MD simulation)  13.350
# 53  Shortened+BFS+RAMDISK    Stage 2\n (Aggregation)   0.000
# 54  Shortened+BFS+RAMDISK       Stage 3\n (Training)  13.145
# 55  Shortened+BFS+RAMDISK      Stage 4\n (Inference)  13.145
# 56  Shortened+BFS+RAMDISK  Stage 1\n (MD simulation)  14.950
# 57  Shortened+BFS+RAMDISK    Stage 2\n (Aggregation)   0.000
# 58  Shortened+BFS+RAMDISK       Stage 3\n (Training)  12.625
# 59  Shortened+BFS+RAMDISK      Stage 4\n (Inference)  12.625

# %%
plt.figure(figsize=(12,4))
ax = sns.barplot(df_all, x='stage', y='value', hue='configuration', 
                 capsize=.029, 
                 errcolor='.3')
ax.set(ylabel='Seconds', xlabel='')
plt.show()

# %%
fig = ax.get_figure()
fig.savefig("ddmd_configurations_comparison.pdf")

# %%
df_all.sort_values(by='value', ascending=False)[:30]
# Out:
#             configuration                      stage   value
# 61           Original+NFS                      Total  92.704
# 60           Original+NFS                      Total  83.377
# 65           Original+BFS                      Total  82.194
# 63           Original+BFS                      Total  81.479
# 62           Original+NFS                      Total  81.388
# 64           Original+BFS                      Total  81.087
# 6            Original+NFS       Stage 3\n (Training)  55.865
# 2            Original+NFS       Stage 3\n (Training)  48.511
# 10           Original+NFS       Stage 3\n (Training)  46.974
# 18           Original+BFS       Stage 3\n (Training)  46.197
# 22           Original+BFS       Stage 3\n (Training)  46.147
# 67          Shortened+NFS                      Total  45.230
# 14           Original+BFS       Stage 3\n (Training)  45.014
# 68          Shortened+NFS                      Total  44.720
# 66          Shortened+NFS                      Total  44.370
# 71          Shortened+BFS                      Total  42.900
# 69          Shortened+BFS                      Total  42.430
# 70          Shortened+BFS                      Total  41.680
# 72  Shortened+BFS+RAMDISK                      Total  40.390
# 74  Shortened+BFS+RAMDISK                      Total  40.200
# 73  Shortened+BFS+RAMDISK                      Total  39.640
# 20           Original+BFS  Stage 1\n (MD simulation)  24.218
# 4            Original+NFS  Stage 1\n (MD simulation)  24.187
# 12           Original+BFS  Stage 1\n (MD simulation)  23.924
# 8            Original+NFS  Stage 1\n (MD simulation)  23.498
# 16           Original+BFS  Stage 1\n (MD simulation)  23.076
# 0            Original+NFS  Stage 1\n (MD simulation)  23.049
# 36          Shortened+BFS  Stage 1\n (MD simulation)  16.570
# 44          Shortened+BFS  Stage 1\n (MD simulation)  16.400
# 28          Shortened+NFS  Stage 1\n (MD simulation)  16.240

# %%
df_all.groupby(['configuration', 'stage']).mean()
# Out:
#                                                      value
# configuration         stage
# Original+BFS          Stage 1\n (MD simulation)  23.739333
#                       Stage 2\n (Aggregation)     1.964000
#                       Stage 3\n (Training)       45.786000
#                       Stage 4\n (Inference)      10.097333
#                       Total                      81.586667
# Original+NFS          Stage 1\n (MD simulation)  23.578000
#                       Stage 2\n (Aggregation)     2.013333
#                       Stage 3\n (Training)       50.450000
#                       Stage 4\n (Inference)       9.781667
#                       Total                      85.823000
# Shortened+BFS         Stage 1\n (MD simulation)  16.323333
#                       Stage 2\n (Aggregation)     0.000000
#                       Stage 3\n (Training)       13.006667
#                       Stage 4\n (Inference)      13.006667
#                       Total                      42.336667
# Shortened+BFS+RAMDISK Stage 1\n (MD simulation)  14.490000
#                       Stage 2\n (Aggregation)     0.000000
#                       Stage 3\n (Training)       12.793333
#                       Stage 4\n (Inference)      12.793333
#                       Total                      40.076667
# Shortened+NFS         Stage 1\n (MD simulation)  16.030000
#                       Stage 2\n (Aggregation)     0.000000
#                       Stage 3\n (Training)       14.371667
#                       Stage 4\n (Inference)      14.371667
#                       Total                      44.773333
